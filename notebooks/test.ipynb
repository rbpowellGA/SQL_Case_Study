# %%
import pandas as pd


df = pd.read_excel('../data/test.xlsx')

# %%
df.head(10)
# Out:
#               name                           jobtitle  \
# 0      Ken Sánchez            Chief Executive Officer
# 1      Rob Walters               Senior Tool Designer
# 2     Dylan Miller   Research and Development Manager
# 3   Diane Margheim  Research and Development Engineer
# 4     Gigi Matthew  Research and Development Engineer
# 5      Kevin Brown                Marketing Assistant
# 6        John Wood               Marketing Specialist
# 7     Mary Dempsey                Marketing Assistant
# 8  Wanida Benshoof                Marketing Assistant
# 9  Terry Eminhizer               Marketing Specialist
#
#                  email address  40+ VacationHours
# 0     ken0@adventure-works.com                 99
# 1     rob0@adventure-works.com                 48
# 2   dylan0@adventure-works.com                 61
# 3   diane1@adventure-works.com                 62
# 4    gigi0@adventure-works.com                 63
# 5   kevin0@adventure-works.com                 42
# ...
